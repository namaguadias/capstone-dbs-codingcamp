# %% [markdown]
# ## 1. Business Understanding
# Proyek ini bertujuan untuk membangun model transfer learning yang dapat mengklasifikasikan 5 jenis penyakit kulit. Teknik yang digunakan adalah Transfer Learning, dengan menggunakan model pre-trained Xception. Model ini akan membantu dalam deteksi penyakit kulit dengan lebih akurat dan lebih cepat, sehingga dapat mendukung diagnosis medis. Metode yang digunakan pada proyek ini adalah Cross-Industry Standard Process for Data Mining (CRISP-DM).

# %% [markdown]
# ## 2. Data Understanding
# Tahap ini berfokus pada persiapan dan pemahaman data yang digunakan dalam model, serta proses eksplorasi dan visualisasi data untuk memahami distribusi gambar penyakit kulit.

# %% [markdown]
# ### 2.1 Data Preparation
# Di sini, kita mengimpor berbagai pustaka yang diperlukan, seperti os, shutil, numpy, pandas, matplotlib, dan lain-lain. Semua pustaka ini membantu dalam manajemen file, pemrosesan gambar, dan visualisasi data.

# %%
# Import Libraries yang diperlukan
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from skimage import io, img_as_ubyte
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tqdm.notebook import tqdm as tq
import cv2

# %% [markdown]
# ### 2.2 Data Loading
# Data gambar dibaca dari folder dataset yang berisi gambar-gambar yang telah dikategorikan berdasarkan jenis penyakit kulit (seperti acne, Vitiligo, dll.).

# %%
combined_dir = "/kaggle/input/dataset/skinDisease"
categories = ['acne', 'hyperpigmentation', 'Nail_psoriasis', 'SJS-TEN', 'Vitiligo']

# %%
# Mengecek jumlah gambar di tiap folder kategori
for category in categories:
    category_dir = os.path.join(combined_dir, category)
    image_files = os.listdir(category_dir)
    print(f"Found {len(image_files)} images in {category} folder.")
# Out:
# Found 1043 images in acne folder.
# Found 1028 images in hyperpigmentation folder.
# Found 1100 images in Nail_psoriasis folder.
# Found 1154 images in SJS-TEN folder.
# Found 1100 images in Vitiligo folder.

# %% [markdown]
# ### 2.3 Data Visualization
# Menampilkan sampel gambar dari masing-masing kategori penyakit kulit dan visualisasi distribusi gambar per kategori.

# %%
# Menampilkan beberapa sampel gambar dari setiap kategori
fig, axes = plt.subplots(len(categories), 5, figsize=(15, 9))
for i, category in enumerate(categories):
    category_dir = os.path.join(combined_dir, category)
    sample_images = random.sample(os.listdir(category_dir), 5)
    for j in range(5):
        image_path = os.path.join(category_dir, sample_images[j])
        img = Image.open(image_path)
        axes[i, j].imshow(img)
        axes[i, j].set_title(f"{category}", fontsize=10)
        axes[i, j].axis('off')
plt.tight_layout()
plt.show()

# %%
# Plotting distribusi gambar per kelas
image_counts = []
for category in categories:
    category_dir = os.path.join(combined_dir, category)
    image_files = os.listdir(category_dir)
    image_counts.append(len(image_files))

# %%
plt.figure(figsize=(8, 5))
bars = plt.bar(categories, image_counts)
plt.title('Distribusi Gambar per Kelas')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, str(yval), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Preparation
# Persiapan data dilakukan dengan membuat DataFrame yang berisi path gambar dan label, kemudian membagi data menjadi data latih dan data uji.

# %%
# Menyusun DataFrame yang berisi path dan label
mypath = '/kaggle/input/dataset/skinDisease'
file_name = []
labels = []
full_path = []
for path, subdirs, files in os.walk(mypath):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)

# %%
# Memasukan variabel yang sudah dikumpulkan pada looping di atas menjadi sebuah dataframe agar rapih
df = pd.DataFrame({"path": full_path, 'file_name': file_name, 'labels': labels})

# %%
# Melihat jumlah data gambar pada masing-masing label
df.groupby(['labels']).size()
# Out:
# labels
# Nail_psoriasis       1100
# SJS-TEN              1154
# Vitiligo             1100
# acne                 1043
# hyperpigmentation    1028
# dtype: int64

# %%
# Variabel yang digunakan pada pemisahan data ini dimana variabel x = data path dan y = data labels
X = df['path']
y = df['labels']

# %%
# Split dataset awal menjadi data train dan test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=300)
df_tr = pd.DataFrame({'path': X_train, 'labels': y_train, 'set': 'train'})
df_te = pd.DataFrame({'path': X_test, 'labels': y_test, 'set': 'test'})

# %% [markdown]
# Data dibagi menjadi dua bagian: data latih (80%) dan data uji (20%) menggunakan train_test_split() dari sklearn.

# %%
# Menyatukan kedalam masing-masing dataframe
df_all = pd.concat([df_tr, df_te], ignore_index=True)

# %%
# Print hasil diatas untuk melihat panjang size data training dan testing
print('train size', len(df_tr))
print('test size', len(df_te))
# Out:
# train size 4340
# test size 1085

# %%
# Menggabungkan DataFrame df_tr dan df_te
dataset_path = "/kaggle/working/finalDataset/"

# %%
for index, row in tq(df_all.iterrows()):
    file_path = row['path']
    if not os.path.exists(file_path):
        file_path = os.path.join(mypath, row['labels'], row['file_name'])

    dest_dir = os.path.join(dataset_path, row['set'], row['labels'])
    os.makedirs(dest_dir, exist_ok=True)

    destination_file_name = os.path.basename(file_path)  
    file_dest = os.path.join(dest_dir, destination_file_name)

    if not os.path.exists(file_dest):
        try:
            shutil.copy2(file_path, file_dest)
        except FileNotFoundError:
            print(f"[File tidak ditemukan] → {file_path}")
# Out:
# 0it [00:00, ?it/s]

# %%
TRAIN_DIR = "/kaggle/working/finalDataset/train"
TEST_DIR = "/kaggle/working/finalDataset/test"

# %%
datagen = ImageDataGenerator(rescale=1./255., validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = datagen.flow_from_directory(
    TRAIN_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', subset='training')
validation_generator = datagen.flow_from_directory(
    TRAIN_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', subset='validation')
test_generator = test_datagen.flow_from_directory(
    TEST_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=False)
# Out:
# Found 3474 images belonging to 5 classes.
# Found 866 images belonging to 5 classes.
# Found 1085 images belonging to 5 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'Nail_psoriasis': 0, 'SJS-TEN': 1, 'Vitiligo': 2, 'acne': 3, 'hyperpigmentation': 4}

# %% [markdown]
# ## 4. Modelling
# Pada tahap ini, kita memuat model Xception yang sudah dilatih sebelumnya (pre-trained) dan menambahkan lapisan-lapisan tambahan untuk menyesuaikan model dengan tugas klasifikasi penyakit kulit.

# %%
# Memuat base model Xception
base_model = Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False

# %% [markdown]
# Model Xception yang sudah dilatih pada dataset ImageNet digunakan sebagai base model dan kita membekukan bobot-bobotnya untuk hanya melatih lapisan tambahan.

# %%
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')  # Keluaran 5 kelas
])

# %% [markdown]
# Menambahkan lapisan-lapisan seperti Conv2D, MaxPooling2D, Flatten, Dense, dan Dropout untuk model akhir.

# %%
# Compile model
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Early stopping custom callback
class EarlyStoppingCustomBothAcc(Callback):
    def __init__(self, target_accuracy=0.98):
        super().__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')

        if train_acc is not None and val_acc is not None:
            if train_acc >= self.target_accuracy and val_acc >= self.target_accuracy:
                print(f"\nEpoch {epoch+1}: Training & Validation Accuracy mencapai target {self.target_accuracy*100:.2f}%. Training model diberhentikan.")
                self.model.stop_training = True

# %%
earlystop_keras = EarlyStopping(
    monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1)

# %%
reduce_learningRate = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# %%
callbacks = [EarlyStoppingCustomBothAcc(target_accuracy=0.98), earlystop_keras, reduce_learningRate]

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 33s 215ms/step - accuracy: 0.4353 - loss: 1.3675 - val_accuracy: 0.8395 - val_loss: 0.4849 - learning_rate: 1.0000e-04
# Epoch 2/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8071 - loss: 0.5475 - val_accuracy: 0.9007 - val_loss: 0.2976 - learning_rate: 1.0000e-04
# Epoch 3/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.8758 - loss: 0.3390 - val_accuracy: 0.9111 - val_loss: 0.2480 - learning_rate: 1.0000e-04
# Epoch 4/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9225 - loss: 0.2247 - val_accuracy: 0.9353 - val_loss: 0.1969 - learning_rate: 1.0000e-04
# Epoch 5/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.9485 - loss: 0.1592 - val_accuracy: 0.9515 - val_loss: 0.1601 - learning_rate: 1.0000e-04
# Epoch 6/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.9672 - loss: 0.1060 - val_accuracy: 0.9515 - val_loss: 0.1608 - learning_rate: 1.0000e-04
# Epoch 7/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 157ms/step - accuracy: 0.9753 - loss: 0.0807 - val_accuracy: 0.9330 - val_loss: 0.2020 - learning_rate: 1.0000e-04
# Epoch 8/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9764 - loss: 0.0671
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 158ms/step - accuracy: 0.9765 - loss: 0.0671 - val_accuracy: 0.9400 - val_loss: 0.2258 - learning_rate: 1.0000e-04
# Epoch 9/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 160ms/step - accuracy: 0.9887 - loss: 0.0465 - val_accuracy: 0.9596 - val_loss: 0.1457 - learning_rate: 2.0000e-05
# Epoch 10/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 160ms/step - accuracy: 0.9911 - loss: 0.0349 - val_accuracy: 0.9457 - val_loss: 0.1555 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 9.

# %% [markdown]
# ## 5. Evaluation
# Setelah melatih model, dilakukan evaluasi untuk mengukur performa model pada data latih, validasi, dan uji.

# %%
# Evaluasi pada data training, validasi, dan testing
loss_train, accuracy_train = model.evaluate(train_generator)
loss_val, accuracy_val = model.evaluate(validation_generator)
loss_test, accuracy_test = model.evaluate(test_generator)
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9988 - loss: 0.0083
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9587 - loss: 0.1397
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9719 - loss: 0.0875

# %% [markdown]
# Evaluasi dilakukan untuk mendapatkan akurasi dan loss dari data latih, validasi, dan uji.

# %%
# Hasil evaluasi
print(f"Training Accuracy: {accuracy_train}, Training Loss: {loss_train}")
print(f"Validation Accuracy: {accuracy_val}, Validation Loss: {loss_val}")
print(f"Test Accuracy: {accuracy_test}, Test Loss: {loss_test}")
# Out:
# Training Accuracy: 0.9997121691703796, Training Loss: 0.006865963339805603
# Validation Accuracy: 0.9595842957496643, Validation Loss: 0.1456819474697113
# Test Accuracy: 0.9612902998924255, Test Loss: 0.11585289984941483

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(12, 5))

# %%
# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training vs Validation Accuracy')

# %% [markdown]
# Menampilkan grafik akurasi dan loss selama pelatihan dan validasi.

# %%
# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()
plt.title('Training vs Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training vs Validation Loss')

# %%
plt.tight_layout()
plt.show()

# %%
# Mendapatkan prediksi
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step

# %%
# Mendapatkan label asli
y_true = test_generator.classes

# %%
# Nama kelas
class_labels = list(test_generator.class_indices.keys())

# %%
# Classification report
print("=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# === Classification Report ===
#                    precision    recall  f1-score   support
#
#    Nail_psoriasis       0.98      1.00      0.99       220
#           SJS-TEN       0.94      0.95      0.95       239
#          Vitiligo       0.93      0.92      0.93       201
#              acne       0.98      0.98      0.98       219
# hyperpigmentation       0.97      0.95      0.96       206
#
#          accuracy                           0.96      1085
#         macro avg       0.96      0.96      0.96      1085
#      weighted avg       0.96      0.96      0.96      1085

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## 6. Deployment
# Setelah model selesai dilatih dan dievaluasi, model disimpan dalam berbagai format untuk di-deploy ke aplikasi lain, seperti TensorFlow Lite untuk penggunaan pada perangkat mobile dan TensorFlow.js untuk penggunaan di web.

# %%
model.save('/kaggle/working/finalModel.h5')

# %%
# Memuat bobot
model.load_weights('/kaggle/working/finalModel.h5')

# %%
# Convert to TF-Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('/kaggle/working/finalModel.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpi9mfnvf4'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_583')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   138411539995472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412912138512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412912139088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411539995664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412912136400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412912138320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355244944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355243984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354773136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354773904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354772752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354774288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354774096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354771792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354775440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354776208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354775056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354776592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354776400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354773520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354771600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354771024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355245904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416355245136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354779664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354780432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354779280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354780816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354780624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354777360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354782736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354777744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354781584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354783120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354782928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354780048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354778128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354778512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354778320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354776016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354786192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354786960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354787152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354782352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354785808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354786768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354784272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354784656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354785040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354784848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138416354782544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508573328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508574672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508575632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508576976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508577744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508576592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508578128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508577936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508575056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508579280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508580048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508578896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508580432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508580240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508581584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508582352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508581968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508579856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508582544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508579664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410508582160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509076240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509075472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509076624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509076432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509074512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509077776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509078544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509077392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509078928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509078736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509075856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509080080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509080848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509079696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509081232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509081040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509078160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509082384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509083152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509082000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509083536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509083344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509080464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509084688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509085456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509084304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509085840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509085648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509082768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509086992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509087760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509086608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509088144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509087952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509085072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509089296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509089680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509089872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509090256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509087376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410509087568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506438224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506438608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506437072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506439760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506440528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506439376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506440912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506442064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506442832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506441680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506443216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506440144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506444368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506445136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506443984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506445520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506445328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506442448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506446672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506447440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506446288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506447824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506447632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506444752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506448976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506449744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506448592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506450128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506449936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506451280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506452048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506450896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506452816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506452240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506449360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506437456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506451856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506945168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506946320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506945936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506947472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506948240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506947088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506948624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506945552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506949776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506950544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506949392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506950928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506950736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506947856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506952080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506952848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506951696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506953232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506953040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506950160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506956304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506955920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506957456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506957264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506954000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506958608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506959376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506954384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506958224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506959760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506959568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506956688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506954768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506955152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506954960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506952656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506959184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138410506960144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558127952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558125648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411539996816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558130064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138411558131984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1749138268.682118      35 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749138268.682149      35 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.

# %%
# Konversi Model ke Format TensorFlow.js (TFJS)
saved_model_path = '/kaggle/working/saved_model'
tfjs_model_dir = '/kaggle/working/tfjs_model'
os.makedirs(tfjs_model_dir, exist_ok=True)
# !tensorflowjs_converter --input_format=tf_saved_model --output_format=tfjs_graph_model {saved_model_path} {tfjs_model_dir}
# Out:
# /bin/bash: line 1: tensorflowjs_converter: command not found

# %%
# Menyimpan model dalam format .keras
model.save('finalModel.keras')

# %% [markdown]
# ## Inferensi

# %%
# Memuat model yang sudah disimpan dalam format .keras
model = tf.keras.models.load_model('/kaggle/working/finalModel.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Menyiapkan gambar yang ingin diprediksi
img_path = '/kaggle/input/fotoprediksi/fotoPrediksiSJS-TEN.jpeg'
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# %%
# Melakukan prediksi
predictions = model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Menampilkan hasil prediksi
class_names = ['Nail_psoriasis', 'SJS-TEN', 'Vitiligo', 'acne', 'hyperpigmentation']  # Ganti dengan nama kelas
predicted_class = class_names[np.argmax(predictions)]

# %%
# Menampilkan gambar dan hasil prediksi
plt.imshow(img)
plt.title(f"Predicted: {predicted_class}")
plt.axis('off')
plt.show()
