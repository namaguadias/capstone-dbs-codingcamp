# %% [markdown]
# ## 1. Business Understanding
# Proyek ini bertujuan untuk membangun model transfer learning yang dapat mengklasifikasikan 5 jenis penyakit kulit. Teknik yang digunakan adalah Transfer Learning, dengan menggunakan model pre-trained Xception. Model ini akan membantu dalam deteksi penyakit kulit dengan lebih akurat dan lebih cepat, sehingga dapat mendukung diagnosis medis. Metode yang digunakan pada proyek ini adalah Cross-Industry Standard Process for Data Mining (CRISP-DM).

# %% [markdown]
# ## 2. Data Understanding
# Tahap ini berfokus pada persiapan dan pemahaman data yang digunakan dalam model, serta proses eksplorasi dan visualisasi data untuk memahami distribusi gambar penyakit kulit.

# %% [markdown]
# ### 2.1 Data Preparation
# Di sini, kita mengimpor berbagai pustaka yang diperlukan, seperti os, shutil, numpy, pandas, matplotlib, dan lain-lain. Semua pustaka ini membantu dalam manajemen file, pemrosesan gambar, dan visualisasi data.

# %%
# Import Libraries yang diperlukan
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from skimage import io, img_as_ubyte
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm as tq
import cv2
# Out:
# 2025-05-31 07:31:45.257642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748676705.463735      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748676705.526368      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### 2.2 Data Loading
# Data gambar dibaca dari folder dataset yang berisi gambar-gambar yang telah dikategorikan berdasarkan jenis penyakit kulit (seperti acne, Vitiligo, dll.).

# %%
combined_dir = "/kaggle/input/dataset/skinDisease"
categories = ['acne', 'hyperpigmentation', 'Nail_psoriasis', 'SJS-TEN', 'Vitiligo']

# %%
# Mengecek jumlah gambar di tiap folder kategori
for category in categories:
    category_dir = os.path.join(combined_dir, category)
    image_files = os.listdir(category_dir)
    print(f"Found {len(image_files)} images in {category} folder.")
# Out:
# Found 1043 images in acne folder.
# Found 1028 images in hyperpigmentation folder.
# Found 1100 images in Nail_psoriasis folder.
# Found 1154 images in SJS-TEN folder.
# Found 1100 images in Vitiligo folder.

# %% [markdown]
# ### 2.3 Data Visualization
# Menampilkan sampel gambar dari masing-masing kategori penyakit kulit dan visualisasi distribusi gambar per kategori.

# %%
# Menampilkan beberapa sampel gambar dari setiap kategori
fig, axes = plt.subplots(len(categories), 5, figsize=(15, 9))
for i, category in enumerate(categories):
    category_dir = os.path.join(combined_dir, category)
    sample_images = random.sample(os.listdir(category_dir), 5)
    for j in range(5):
        image_path = os.path.join(category_dir, sample_images[j])
        img = Image.open(image_path)
        axes[i, j].imshow(img)
        axes[i, j].set_title(f"{category}", fontsize=10)
        axes[i, j].axis('off')
plt.tight_layout()
plt.show()

# %%
# Plotting distribusi gambar per kelas
image_counts = []
for category in categories:
    category_dir = os.path.join(combined_dir, category)
    image_files = os.listdir(category_dir)
    image_counts.append(len(image_files))

# %%
plt.figure(figsize=(8, 5))
bars = plt.bar(categories, image_counts)
plt.title('Distribusi Gambar per Kelas')
plt.xlabel('Kelas')
plt.ylabel('Jumlah Gambar')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5, str(yval), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Preparation
# Persiapan data dilakukan dengan membuat DataFrame yang berisi path gambar dan label, kemudian membagi data menjadi data latih dan data uji.

# %%
# Menyusun DataFrame yang berisi path dan label
mypath = '/kaggle/input/dataset/skinDisease'
file_name = []
labels = []
full_path = []
for path, subdirs, files in os.walk(mypath):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)

# %%
# Memasukan variabel yang sudah dikumpulkan pada looping di atas menjadi sebuah dataframe agar rapih
df = pd.DataFrame({"path": full_path, 'file_name': file_name, 'labels': labels})

# %%
# Melihat jumlah data gambar pada masing-masing label
df.groupby(['labels']).size()
# Out:
# labels
# Nail_psoriasis       1100
# SJS-TEN              1154
# Vitiligo             1100
# acne                 1043
# hyperpigmentation    1028
# dtype: int64

# %%
# Variabel yang digunakan pada pemisahan data ini dimana variabel x = data path dan y = data labels
X = df['path']
y = df['labels']

# %%
# Split dataset awal menjadi data train dan test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=300)
df_tr = pd.DataFrame({'path': X_train, 'labels': y_train, 'set': 'train'})
df_te = pd.DataFrame({'path': X_test, 'labels': y_test, 'set': 'test'})

# %% [markdown]
# Data dibagi menjadi dua bagian: data latih (80%) dan data uji (20%) menggunakan train_test_split() dari sklearn.

# %%
# Menyatukan kedalam masing-masing dataframe
df_all = pd.concat([df_tr, df_te], ignore_index=True)

# %%
# Print hasil diatas untuk melihat panjang size data training dan testing
print('train size', len(df_tr))
print('test size', len(df_te))
# Out:
# train size 4340
# test size 1085

# %%
# Menggabungkan DataFrame df_tr dan df_te
dataset_path = "/kaggle/working/finalDataset/"

# %%
for index, row in tq(df_all.iterrows()):
    file_path = row['path']
    if not os.path.exists(file_path):
        file_path = os.path.join(mypath, row['labels'], row['file_name'])

    dest_dir = os.path.join(dataset_path, row['set'], row['labels'])
    os.makedirs(dest_dir, exist_ok=True)

    destination_file_name = os.path.basename(file_path)  
    file_dest = os.path.join(dest_dir, destination_file_name)

    if not os.path.exists(file_dest):
        try:
            shutil.copy2(file_path, file_dest)
        except FileNotFoundError:
            print(f"[File tidak ditemukan] → {file_path}")
# Out:
# 0it [00:00, ?it/s]

# %%
TRAIN_DIR = "/kaggle/working/finalDataset/train"
TEST_DIR = "/kaggle/working/finalDataset/test"

# %%
datagen = ImageDataGenerator(rescale=1./255., validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = datagen.flow_from_directory(
    TRAIN_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', subset='training')
validation_generator = datagen.flow_from_directory(
    TRAIN_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', subset='validation')
test_generator = test_datagen.flow_from_directory(
    TEST_DIR, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=False)
# Out:
# Found 3474 images belonging to 5 classes.
# Found 866 images belonging to 5 classes.
# Found 1085 images belonging to 5 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'Nail_psoriasis': 0, 'SJS-TEN': 1, 'Vitiligo': 2, 'acne': 3, 'hyperpigmentation': 4}

# %% [markdown]
# ## 4. Modelling
# Pada tahap ini, kita memuat model Xception yang sudah dilatih sebelumnya (pre-trained) dan menambahkan lapisan-lapisan tambahan untuk menyesuaikan model dengan tugas klasifikasi penyakit kulit.

# %%
# Memuat base model Xception
base_model = Xception(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False
# Out:
# I0000 00:00:1748676770.829673      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1748676770.830349      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Model Xception yang sudah dilatih pada dataset ImageNet digunakan sebagai base model dan kita membekukan bobot-bobotnya untuk hanya melatih lapisan tambahan.

# %%
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')  # Keluaran 5 kelas
])

# %% [markdown]
# Menambahkan lapisan-lapisan seperti Conv2D, MaxPooling2D, Flatten, Dense, dan Dropout untuk model akhir.

# %%
# Compile model
model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Early stopping custom callback
class EarlyStoppingCustomBothAcc(Callback):
    def __init__(self, target_accuracy=0.98):
        super().__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')

        if train_acc is not None and val_acc is not None:
            if train_acc >= self.target_accuracy and val_acc >= self.target_accuracy:
                print(f"\nEpoch {epoch+1}: Training & Validation Accuracy mencapai target {self.target_accuracy*100:.2f}%. Training model diberhentikan.")
                self.model.stop_training = True

# %%
earlystop_keras = EarlyStopping(
    monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1)

# %%
reduce_learningRate = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# %%
callbacks = [EarlyStoppingCustomBothAcc(target_accuracy=0.98), earlystop_keras, reduce_learningRate]

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748676780.472459     105 service.cc:148] XLA service 0x7cfa38412400 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748676780.473535     105 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748676780.473557     105 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1748676781.435898     105 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/109 ━━━━━━━━━━━━━━━━━━━━ 29:09 16s/step - accuracy: 0.3125 - loss: 1.6862
# I0000 00:00:1748676789.890320     105 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 44s 261ms/step - accuracy: 0.4592 - loss: 1.3159 - val_accuracy: 0.8684 - val_loss: 0.4327 - learning_rate: 1.0000e-04
# Epoch 2/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.8185 - loss: 0.5256 - val_accuracy: 0.9065 - val_loss: 0.2854 - learning_rate: 1.0000e-04
# Epoch 3/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 159ms/step - accuracy: 0.8811 - loss: 0.3247 - val_accuracy: 0.9330 - val_loss: 0.2109 - learning_rate: 1.0000e-04
# Epoch 4/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9266 - loss: 0.2075 - val_accuracy: 0.9446 - val_loss: 0.1796 - learning_rate: 1.0000e-04
# Epoch 5/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9581 - loss: 0.1313 - val_accuracy: 0.9561 - val_loss: 0.1442 - learning_rate: 1.0000e-04
# Epoch 6/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.9743 - loss: 0.0937 - val_accuracy: 0.9573 - val_loss: 0.1478 - learning_rate: 1.0000e-04
# Epoch 7/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 21s 191ms/step - accuracy: 0.9813 - loss: 0.0765 - val_accuracy: 0.9469 - val_loss: 0.1668 - learning_rate: 1.0000e-04
# Epoch 8/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9882 - loss: 0.0488
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9882 - loss: 0.0488 - val_accuracy: 0.9480 - val_loss: 0.1678 - learning_rate: 1.0000e-04
# Epoch 9/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.9909 - loss: 0.0329 - val_accuracy: 0.9596 - val_loss: 0.1354 - learning_rate: 2.0000e-05
# Epoch 10/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9918 - loss: 0.0332 - val_accuracy: 0.9596 - val_loss: 0.1343 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 9.

# %% [markdown]
# ## 5. Evaluation
# Setelah melatih model, dilakukan evaluasi untuk mengukur performa model pada data latih, validasi, dan uji.

# %%
# Evaluasi pada data training, validasi, dan testing
loss_train, accuracy_train = model.evaluate(train_generator)
loss_val, accuracy_val = model.evaluate(validation_generator)
loss_test, accuracy_test = model.evaluate(test_generator)
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 158ms/step - accuracy: 0.9993 - loss: 0.0068
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9582 - loss: 0.1498
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 358ms/step - accuracy: 0.9768 - loss: 0.0769

# %% [markdown]
# Evaluasi dilakukan untuk mendapatkan akurasi dan loss dari data latih, validasi, dan uji.

# %%
# Hasil evaluasi
print(f"Training Accuracy: {accuracy_train}, Training Loss: {loss_train}")
print(f"Validation Accuracy: {accuracy_val}, Validation Loss: {loss_val}")
print(f"Test Accuracy: {accuracy_test}, Test Loss: {loss_test}")
# Out:
# Training Accuracy: 0.9997121691703796, Training Loss: 0.006190627347677946
# Validation Accuracy: 0.9595842957496643, Validation Loss: 0.13541904091835022
# Test Accuracy: 0.964976966381073, Test Loss: 0.11138065904378891

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(12, 5))

# %%
# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training vs Validation Accuracy')

# %% [markdown]
# Menampilkan grafik akurasi dan loss selama pelatihan dan validasi.

# %%
# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()
plt.title('Training vs Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training vs Validation Loss')

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Deployment
# Setelah model selesai dilatih dan dievaluasi, model disimpan dalam berbagai format untuk di-deploy ke aplikasi lain, seperti TensorFlow Lite untuk penggunaan pada perangkat mobile dan TensorFlow.js untuk penggunaan di web.

# %%
model.save('/kaggle/working/finalModel.h5')

# %%
# Convert to TF-Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('/kaggle/working/finalModel.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpobzzrcx_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_132')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   137417844228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844161424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844162192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417843469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844161616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842088016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842089744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842090320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842088592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842089360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842088208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842091856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842092624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844160848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842092240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842089936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842092048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842092432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842086096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842084368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842085136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842084560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842093776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842097616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842097232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842091472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842097808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842096656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842097424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842607888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842094544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842607120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842608272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842606160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842094928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842095312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842095120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842089168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842611344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842612112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842610960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842612496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842612304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842609040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842613648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842614416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842609424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842613264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842614800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842614608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842611728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842609808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842610192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842610000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842607696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842615952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842616720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842615568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842617104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842616912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842614032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842618256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842619024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842617872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842619408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842619216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842616336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842620560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842621328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842620176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842622096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842621520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842618640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842618832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417842621136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685304528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685303568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685304336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685303376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685306064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685306832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685305680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685307216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685307024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685304912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685308368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685309136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685307984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685309520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685309328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685306448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685310672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685311440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685310288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685311824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685311632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685308752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685312976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685313744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685312592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685314128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685313936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685311056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685315280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685316048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685314896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685316432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685316240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685313360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685317584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685318352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685317200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685318736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685318544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685315664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685315856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685318160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685779472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685778512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685304144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685778704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685781008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685781776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685780624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685782160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685779856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685783312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685784080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685782928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685784464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685784272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685781392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685785616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685786384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685785232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685786768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685786576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685783696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685787920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685788688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685787536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685789072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685788880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685786000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685790224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685790992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685789840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685791376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685788304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685793296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685792144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685793680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685793488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685793104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685794448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684173840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684172880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417685794064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684173072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684175184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684175952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684174800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684176336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684176144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684173648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684177488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684178256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684177104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684178640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684178448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684175568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684180752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684177872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684181712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684183248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684183056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684180176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684185360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684698896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684699664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684698512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684700048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684699856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684697552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684701200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684701968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684700816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684702352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684702160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684699280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684703504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684704272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684703120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684704656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684704464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684701584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684705808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684706576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684705424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684706960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684706768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684703888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417844229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684709264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684708688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684710032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684706192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137417684710800: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1748677044.787071      35 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1748677044.787112      35 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1748677044.893123      35 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.5)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.10)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.73)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (14.0.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.13.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.72.0rc1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.9.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.14.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.2)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 3.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Convert to TFJS
# !tensorflowjs_converter --input_format=keras /kaggle/working/finalModel.h5 /kaggle/working/finalModel_tfjs
# Out:
# 2025-05-31 07:37:35.052533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748677055.075920     453 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748677055.082719     453 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# failed to lookup keras version from the file,
#     this is likely a weight only file

# %%
# Menyimpan model dalam format .keras
model.save('finalModel.keras')
